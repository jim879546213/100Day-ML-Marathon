# %% [markdown]
# # 作業一

# %% [markdown]
# Data: Heart Disease UCI
# 1. 為何重要:現代人慢性病比率上升，藉由相對客觀的數據去預估發病程度或機率，可以輔助醫生的判斷，減少誤判或者延遲診斷的機率
# 2. 資料來源:Hungarian Institute of Cardiology、University Hospital, Zurich, Switzerland、University Hospital, Basel,                        Switzerland、V.A. Medical Center, Long Beach and Cleveland Clinic Foundation
# 3. 資料型態:csv(heart.csv,[304,14])
# 4. 想解決的問題如何評估:找出13種參數與發病程度(0,1,2,3,4)的相關性，希望更進一步找出參數與疾病的相關性，並希望藉由各種參數預估病人發病情況

# %% [markdown]
# # 作業二

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題:提高每位司機一日的載客量；假設載客量與[地區,客源,服務品質,知名度,汽車清潔度,載客時段...]有關係，找出提升載客量的關鍵特點
# 2. 根據本公司的載客app內的數據
# 3. 資料型態:csv
# 4. 找出各個特點與載客量的關聯性，並且量化成分數，鼓勵司機能追求更高的分數(可以以獎金鼓勵)，以達到公司整體最大效益

# %% [markdown]
# # 作業三

# %% [markdown]
# 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt
def mean_squared_error(y, y_hat):
    """
    計算 MSE
    Args:
        - y: 實際值
        - y_hat: 預測值
    Return:
        - mse: MSE
    """
    mse = np.mean((y-y_hat)**2)
    return mse
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 191.228
# The Mean absolute error is 10.838
